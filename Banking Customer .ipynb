# %% [markdown]
# <a href="https://colab.research.google.com/github/Ogana32/solomon/blob/main/Banking%20Customer%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
transaction = pd.read_csv('/content/drive/MyDrive/bank_transactions.csv')
transaction.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1            T2   C2142763      4/4/57          M      JHAJJAR
# 2            T3   C4417068    26/11/96          F       MUMBAI
# 3            T4   C5342380     14/9/73          F       MUMBAI
# 4            T5   C9031234     24/3/88          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
# 1             2270.69          2/8/16           141858
# 2            17874.44          2/8/16           142712
# 3           866503.21          2/8/16           142714
# 4             6714.43          2/8/16           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %%
# transaction.isnull().values.any()
# transaction.isnull().sum()

transaction['TransactionTime'] = transaction['TransactionTime'].astype(str)

# %%
transaction = transaction[transaction['TransactionTime'].str.len() >= 6]

transaction.isnull().sum()
transaction = transaction.dropna()
transaction.info()
transaction = transaction.drop_duplicates()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 916039 entries, 0 to 1048566
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   TransactionID            916039 non-null  object
#  1   CustomerID               916039 non-null  object
#  2   CustomerDOB              916039 non-null  object
#  3   CustGender               916039 non-null  object
#  4   CustLocation             916039 non-null  object
#  5   CustAccountBalance       916039 non-null  float64
#  6   TransactionDate          916039 non-null  object
#  7   TransactionTime          916039 non-null  object
#  8   TransactionAmount (INR)  916039 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 69.9+ MB

# %%
from datetime import datetime as dt

transaction['TransactionTime'] = transaction['TransactionTime'].apply(lambda x: dt.strptime(x,'%H%M%S').time())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-6c277e9c4946> in <cell line: 3>()
#       1 from datetime import datetime as dt
#       2
# ----> 3 transaction['TransactionTime'] = transaction['TransactionTime'].apply(lambda x: dt.strptime(x,'%H%M%S').time())
#       4
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4762             args=args,
#    4763             kwargs=kwargs,
# -> 4764         ).apply()
#    4765
#    4766     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1207
#    1208         # self.func is Callable
# -> 1209         return self.apply_standard()
#    1210
#    1211     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
transaction.head()
transaction['TransactionTime'] = pd.to_datetime(transaction['TransactionTime'], format='%H:%M:%S').dt.time
transaction.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1            T2   C2142763      4/4/57          M      JHAJJAR
# 2            T3   C4417068    26/11/96          F       MUMBAI
# 3            T4   C5342380     14/9/73          F       MUMBAI
# 4            T5   C9031234     24/3/88          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate TransactionTime  TransactionAmount (INR)
# 0            17819.05          2/8/16        14:32:07                     25.0
# 1             2270.69          2/8/16        14:18:58                  27999.0
# 2            17874.44          2/8/16        14:27:12                    459.0
# 3           866503.21          2/8/16        14:27:14                   2060.0
# 4             6714.43          2/8/16        18:11:56                   1762.5

# %%
transaction.head(30)
# Out:
#    TransactionID CustomerID CustomerDOB CustGender              CustLocation  \
# 0             T1   C5841053     10/1/94          F                JAMSHEDPUR
# 1             T2   C2142763      4/4/57          M                   JHAJJAR
# 2             T3   C4417068    26/11/96          F                    MUMBAI
# 3             T4   C5342380     14/9/73          F                    MUMBAI
# 4             T5   C9031234     24/3/88          F               NAVI MUMBAI
# 5             T6   C1536588     8/10/72          F                  ITANAGAR
# 6             T7   C7126560     26/1/92          F                    MUMBAI
# 7             T8   C1220223     27/1/82          M                    MUMBAI
# 8             T9   C8536061     19/4/88          F                   GURGAON
# 9            T10   C6638934     22/6/84          M                    MUMBAI
# 10           T11   C5430833     22/7/82          M                    MOHALI
# ...

# %%
transaction['TransactionTime'] = transaction['TransactionTime'].apply(lambda x : x.strftime('%H:%M'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-22fd70c705f3> in <cell line: 1>()
# ----> 1 transaction['TransactionTime'] = transaction['TransactionTime'].apply(lambda x : x.strftime('%H:%M'))
#       2 transaction.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4762             args=args,
#    4763             kwargs=kwargs,
# -> 4764         ).apply()
#    4765
#    4766     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1207
#    1208         # self.func is Callable
# -> 1209         return self.apply_standard()
#    1210
#    1211     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1287         #  Categorical (GH51645).
# ...

# %%
transaction['TransactionTime'] = pd.to_datetime(transaction['TransactionTime'], format = '%H:%M' )

# %%
transaction.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1            T2   C2142763      4/4/57          M      JHAJJAR
# 2            T3   C4417068    26/11/96          F       MUMBAI
# 3            T4   C5342380     14/9/73          F       MUMBAI
# 4            T5   C9031234     24/3/88          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate TransactionTime  TransactionAmount (INR)
# 0            17819.05          2/8/16           14:32                     25.0
# 1             2270.69          2/8/16           14:18                  27999.0
# 2            17874.44          2/8/16           14:27                    459.0
# 3           866503.21          2/8/16           14:27                   2060.0
# 4             6714.43          2/8/16           18:11                   1762.5

# %%
transaction.head(100)
# Out:
#     TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0              T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1              T2   C2142763      4/4/57          M      JHAJJAR
# 2              T3   C4417068    26/11/96          F       MUMBAI
# 3              T4   C5342380     14/9/73          F       MUMBAI
# 4              T5   C9031234     24/3/88          F  NAVI MUMBAI
# ..            ...        ...         ...        ...          ...
# 104          T105   C7924053     15/4/71          F      KOLKATA
# 105          T106   C7118047     27/8/67          M        DELHI
# 106          T107   C5836729      1/5/77          M        THANE
# 107          T108   C5712211     6/11/81          M      KOLKATA
# 108          T109   C5910145    14/10/77          M      GURGAON
#
#      CustAccountBalance TransactionDate TransactionTime  \
# 0              17819.05          2/8/16           14:32
# 1               2270.69          2/8/16           14:18
# ...

# %%
transaction['TransactionTime'] = transaction['TransactionTime'].apply(lambda x: x.strftime('%H:%M'))

# %%
transaction.head()
transaction.info()
transaction.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 916039 entries, 0 to 1048566
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   TransactionID            916039 non-null  object
#  1   CustomerID               916039 non-null  object
#  2   CustomerDOB              916039 non-null  object
#  3   CustGender               916039 non-null  object
#  4   CustLocation             916039 non-null  object
#  5   CustAccountBalance       916039 non-null  float64
#  6   TransactionDate          916039 non-null  object
#  7   TransactionTime          916039 non-null  object
#  8   TransactionAmount (INR)  916039 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 69.9+ MB
# TransactionID              0
# CustomerID                 0
# CustomerDOB                0
# CustGender                 0
# CustLocation               0
# CustAccountBalance         0
# ...

# %%
print(transaction['TransactionTime'].unique())
# Out:
# ['14:32' '14:18' '14:27' '18:11' '17:39' '17:38' '17:05' '19:28' '19:24'
#  '20:41' '20:51' '20:38' '12:57' '12:47' '12:21' '15:28' '10:53' '10:47'
#  '12:56' '12:48' '16:05' '18:36' '16:06' '16:07' '18:27' '12:59' '18:29'
#  '18:09' '13:25' '22:11' '22:09' '22:20' '22:26' '22:31' '10:00' '13:31'
#  '14:17' '16:56' '16:59' '20:28' '20:29' '20:26' '20:27' '20:25' '10:58'
#  '18:04' '18:05' '17:37' '18:08' '19:41' '19:47' '20:40' '20:42' '21:06'
#  '20:32' '22:08' '12:16' '12:20' '12:17' '12:01' '14:48' '16:53' '16:55'
#  '17:00' '17:02' '16:23' '17:41' '17:43' '18:24' '18:26' '18:54' '20:06'
#  '20:33' '20:35' '22:54' '23:00' '22:59' '11:06' '11:05' '10:55' '17:51'
#  '18:32' '18:31' '18:39' '20:11' '20:13' '20:16' '19:49' '14:39' '22:48'
#  '11:03' '10:08' '16:52' '16:40' '18:12' '15:52' '16:01' '22:46' '22:50'
#  '20:08' '20:15' '20:17' '19:59' '20:01' '11:08' '11:55' '11:56' '12:06'
#  '17:21' '17:30' '17:29' '12:15' '15:58' '15:44' '17:16' '18:23' '18:51'
# ...

# %%
transaction['CustomerDOB'] = pd.to_datetime(transaction['CustomerDOB'])

todays_date = pd.Timestamp.today().date()

todays_date_array = pd.to_datetime([todays_date]*len(transaction), format = '%Y-%m-%d')

# Do not convert todays_date to string
#formatted_date = todays_date.strftime('%d-%m-%y')

transaction['Age'] = (todays_date_array - transaction['CustomerDOB'])
#transaction.head()
# Out:
# <ipython-input-39-5023bda0a585>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   transaction['CustomerDOB'] = pd.to_datetime(transaction['CustomerDOB'])

# %%
transaction.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  1994-10-01          F   JAMSHEDPUR
# 1            T2   C2142763  2057-04-04          M      JHAJJAR
# 2            T3   C4417068  1996-11-26          F       MUMBAI
# 3            T4   C5342380  2073-09-14          F       MUMBAI
# 4            T5   C9031234  1988-03-24          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate TransactionTime  \
# 0            17819.05          2/8/16           14:32
# 1             2270.69          2/8/16           14:18
# 2            17874.44          2/8/16           14:27
# 3           866503.21          2/8/16           14:27
# 4             6714.43          2/8/16           18:11
#
#    TransactionAmount (INR)         Age
# 0                     25.0  10908 days
# 1                  27999.0 -11923 days
# 2                    459.0  10121 days
# 3                   2060.0 -17930 days
# 4                   1762.5  13290 days

# %%
transaction = transaction[transaction['Age'] >= treshhold]

# %%
treshhold = pd.Timedelta(days = 6000)

# %%
transaction['Age']= transaction['Age']/ pd.Timedelta(days=365.2425)

# %%
transaction['Age'] = np.ceil(transaction['Age']).astype(int)

# %%
transaction.describe()
transaction = transaction[transaction['Age']<=75]
transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783162 entries, 0 to 1048566
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   TransactionID            783162 non-null  object
#  1   CustomerID               783162 non-null  object
#  2   CustomerDOB              783162 non-null  datetime64[ns]
#  3   CustGender               783162 non-null  object
#  4   CustLocation             783162 non-null  object
#  5   CustAccountBalance       783162 non-null  float64
#  6   TransactionDate          783162 non-null  object
#  7   TransactionTime          783162 non-null  object
#  8   TransactionAmount (INR)  783162 non-null  float64
#  9   Age                      783162 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 65.7+ MB

# %%
Transactionn = transaction.dropna(subset=['CustAccountBalance'])
Transactionn = transactions.dropna(subset=['CustAccountBalance'])

# %%
transactions = transactions.dropna()
transactions.drop_duplicates
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1041614 entries, 0 to 1048566
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1041614 non-null  object
#  1   CustomerID               1041614 non-null  object
#  2   CustomerDOB              1041614 non-null  object
#  3   CustGender               1041614 non-null  object
#  4   CustLocation             1041614 non-null  object
#  5   CustAccountBalance       1041614 non-null  float64
#  6   TransactionDate          1041614 non-null  object
#  7   TransactionTime          1041614 non-null  object
#  8   TransactionAmount (INR)  1041614 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 79.5+ MB

# %%
transactions['TransactionTime']=transactions['TransactionTime'].dt.time
transactions.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-3a67b2548a39> in <cell line: 1>()
# ----> 1 transactions['TransactionTime']=transactions['TransactionTime'].dt.time
#       2 transactions.info()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
transactions['TransactionTime'] = transactions['TransactionTime'].apply(lambda x: x.strftime('%H:%M:%S')
# Out:
#   File "<ipython-input-104-18ab70dcd3f0>", line 1
#     transactions['TransactionTime'] = transactions['TransactionTime'].apply(lambda x: x.strftime('%H:%M:%S')
#                                                                                                             ^
# SyntaxError: incomplete input

# %%
transactions.to_excel('/content/drive/MyDrive/bank_transactions.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     954         try:
# --> 955             writer._write_cells(
#     956                 formatted_cells,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in _write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     503                 for k, v in style_kwargs.items():
# --> 504                     setattr(xcell, k, v)
#     505
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/styleable.py in __set__(self, instance, value)
#      25             instance._style = StyleArray()
# ---> 26         setattr(instance._style, self.key, coll.add(value))
#      27
#
# ...

# %%
transaction.to_excel('/content/drive/MyDrive/banks_transactions.xlsx')
